# %%
#1

# %%
def fun1(a):
    if a==1:
        return 1
    return a*fun1(a-1)

# %%
fun1(5)
# Out:
# 120

# %%
#2

# %%
def relation_to_luke(a):
    if a=='Darth Vader':
        b='father'
    elif a=='Leia':
        b='sister'
    elif a=='Han':
        b='brother in law'
    else:
        b='droid'
    return "Luke, I am your "+b

# %%
relation_to_luke('Darth Vader')
# Out:
# 'Luke, I am your father'

# %%
#3

# %%
def fun3(a):
    c=0
    while a!=0:
        c+=1
        a//=10
    return c

# %%
fun3(123)
# Out:
# 3

# %%
#4

# %%
def fun4(a):
    m=1
    for i in range(1,a+1):
        x=lambda n: 1 if n<=1 else n*x(n-1)
        m*=x(i)
    return m

# %%
fun4(5)
# Out:
# 34560

# %%
#5

# %%
def fun5(*a):
    s=0
    for i in a:
        s+=i*i
    return s

# %%
fun5(1,2,3)
# Out:
# 14

# %%
#6

# %%
def fun6(a,b,c):
    if c=='+':
        return a+b
    if c=='-':
        return a-b
    if c=='*':
        return a*b
    if c=='/':
        return a/b

# %%
fun6(3,2,'+')
# Out:
# 5

# %%
#7

# %%
def fun7(a):
    c=''
    for i in range(1,a+1):
        if i>1:
            c+=','
        if i%2!=0:
            c+='"I CAN"'
        else:
            c+='"I WILL"'
    return c

# %%
print(fun7(3))
# Out:
# "I CAN","I WILL","I CAN"

# %%
#8

# %%
def fun8(a):
    s=set(a)
    p=0
    for i in s:
        p+=a.count(i)//2
    return p

# %%
fun8([1,2,1,2,1,3,2])
# Out:
# 2

# %%
#9

# %%
def fun9(a,b):
    c=set(a+b)
    d=max(c)-min(c)
    if d+1==len(c):
        return True
    return False

# %%
fun9([7,4,5,1],[2,3,6])
# Out:
# True

# %%
fun9([1,4,6,5],[2,7,8,9])
# Out:
# False

# %%
#10

# %%
def fun10(d):
    return round((d['sell_price']-d['cost_price'])*d['inventory'])

# %%
fun10({'cost_price':32.67,'sell_price':45.00,'inventory':1200})
# Out:
# 14796
